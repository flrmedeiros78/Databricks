# %%
# %sql
list '/Volumes/dbacademy/get_started_de/myfiles';

# %%
# %sql
USE CATALOG dbacademy;
USE SCHEMA get_started_de;

CREATE TABLE IF NOT EXISTS employes_bronze
(
     ID INT
    ,FirstName STRING
    ,Country STRING
    ,Role STRING 
);

# %%
# Popula a tabela employes_bronze com os dois arquivos myfiles/*csv
result = spark.sql("""
COPY INTO employes_bronze
FROM '/Volumes/dbacademy/get_started_de/myfiles/'
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true', 'inferSchema' = 'true')
""")
display(result)

# %%
# %sql
select * from employes_bronze;
