-- %%
USE CATALOG dbacademy;
USE SCHEMA get_started_de;

SELECT * FROM delta_employes_01;

-- %%
select * from delta_employes_02;

-- %%
-- Adicionar os dados da tabela delta_employes_02 na tabela delta_employes_01
INSERT INTO delta_employes_01 
( ID, FirstName, Country, Role)
VALUES --(5, 'Maria', 'Brasil', 'Data Engineer'),
       (6, 'Aiden', 'Australia', 'Data Analyst');

-- %%
select * from delta_employes_01;

-- %%
update delta_employes_01 set
Role = 'Senior Data Engineer'
where Id = 5;

-- %%
select * from delta_employes_01;

-- %%
delete from delta_employes_01
where id = 6;

-- %%
select * from delta_employes_01;

-- %%
DESCRIBE HISTORY delta_employes_01;
