# %%
# %sql
USE CATALOG dbacademy;
USE SCHEMA get_started_de;

# %%
# %sql

CREATE TABLE IF NOT EXISTS cta AS
SELECT ID, FirstName, Country, Role
FROM read_files('/Volumes/dbacademy/get_started_de/myfiles/employees.csv',
format => 'csv',
header => True,
inferSchema => True);

# %%
# %sql
select * from cta;

# %%
# Crie uma tabela usando a UI de upload do Catalog Explorer
try:
    display(spark.sql("SELECT * FROM employees_ui"))
except Exception as e:
    if "TABLE OR VIEW NOT FOUND" in str(e):
        print("A tabela 'employees_ui' ainda não existe" )
        print("Conclua as etapas de upload da interface do usuário acima e execute novamente está célula")
    else:
        raise e

# %%
# %sql
SHOW TABLES;

# %% [markdown]
# Crie uma tabela chamadapractice_copyinto com 4 colunas:ID (INT),FirstName (STRING),Country (STRING),Role (STRING).

# %%
# %sql
use catalog dbacademy;
use schema get_started_de;

CREATE TABLE IF NOT EXISTS employees_copyinto
(
    ID INT,
    FirstName STRING,
    Country STRING,
    Role STRING
);

# %%
# %sql
select * from employees_copyinto;

# %% [markdown]
# Carregar dados com COPY INTO

# %%
#TODOS: RUN COPY INTO
#COPY INTO employees_copyinto
#from read_files('/Volumes/dbacademy/get_started_de/myfiles/employees.csv')

# replace do arquivo employees.csv
result = spark.sql("""
    COPY INTO employees_copyinto
    FROM '/Volumes/dbacademy/get_started_de/myfiles/employees.csv'
    FILEFORMAT = csv
    FORMAT_OPTIONS ('HEADER' = 'True', 'inferschema' = 'True')
""")
result.display()

# %%
# %sql
select * from employees_copyinto

# %%
# %sql
USE CATALOG dbacademy;
USE SCHEMA get_started_de;
DROP TABLE employes_cpyinto_v2

# %%
# %sql

CREATE TABLE IF NOT EXISTS employes_copyinto
(
    ID INT,
    FirstName STRING,
    Country STRING,
    Role STRING
);

# %%
# %sql
SELECT * FROM employes_copyinto;

# %%
# %sql
USE CATALOG dbacademy;
USE SCHEMA get_started_de;

# %%
# %sql
INSERT INTO employes_copyinto
SELECT ID, FirstName, Country, Role
FROM delta_employes_01
UNION ALL
SELECT ID, FirstName, Country, Role
FROM delta_employes_02;

# %%
# %sql
SELECT * FROM employes_copyinto

# %%
# %sql
DESCRIBE HISTORY employes_copyinto;
