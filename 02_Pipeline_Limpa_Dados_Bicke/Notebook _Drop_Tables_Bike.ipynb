-- %%
USE CATALOG dbacademy;
USE SCHEMA default;

DROP TABLE IF EXISTS tb_bronze_bike_eventos;
DROP TABLE IF EXISTS tb_silver_bike_eventos;
DROP TABLE IF EXISTS tb_gold_bike_eventos;
DROP TABLE IF EXISTS tb_gold_bike_eventos_mv;
